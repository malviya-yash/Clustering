# %% [markdown]
# #Clustering Assignment

# %% [markdown]
# Q1. What is the difference between K-Means and Hierarchical Clustering?
# Provide a use case for each.
#
#     - * K-Means makes groups by assigning points to the nearest cluster center, and works fast with big data.
#
#       * Hierachical Clustering builds a tree of cluster by merging or slitting groups step-by merging or splitting groups step-by-step, useful for seeing nested relationships.
#
#       Use Case:
#
#         * K-Means: Segmenting customers by spending habits.
#
#         * Hierachical: Arranging genes by similarity in biology.
#
# Q2. : Explain the purpose of the Silhouette Score in evaluating clustering
# algorithms.
#
#       - * The Silhouette Score shows how well each point fits in its cluster versus neighboring cluster.
#
#         * High scores mean points sit nicely with their group, helping tell if clusters are well-separated.
#
# Q3. What are the core parameters of DBSCAN, and how do they influence the
# clustering process?
#
#     - * eps: Sets how close points need to be to link up.
#
#       * min_samples: Minimum number of neighbours needed to form a cluster.
#
#       Both control how big clusters are and how easily points are marked as outliers.
#
# Q4. Why is feature scaling important when applying clustering algorithms like
# K-Means and DBSCAN?
#
#     - * Scaling puts all features on the same scale so clusturing isn't biased toward bigger numbers.
#
#       * It prevents distance-based mehtods like K-Means and DBSCAN from grouping points incorrectly.
#
#
# Q5. What is the Elbow Method in K-Means clustering and how does it help
# determine the optimal number of clusters?
#
#     - * Elbow Method finds the best number of clusters by plotting cluster count vs error.
#
#       * The "elbow" point is where adding more clusters stops making a big diffrence hinting at the optimal cloice.
#
# Q10. You are working as a data analyst at an e-commerce company. The
# marketing team wants to segment customers based on their purchasing behavior to run
# targeted promotions. The dataset contains customer demographics and their product
# purchase history across categories.
#
#       - E-Commerce Customer Segmentation Workflow
#
#           * Algorithms: Try K-Means for speed, or Hierachical for detailed insight .
#
#           * Preprocessing: Fix missing values, scale features so shopping counts and ages don't skew results.
#
#           * Clusters Count: Use the Elbow Method or Silhouette Score to pick the best number.
#
#           * Marketing Benifit: Teams can target promotions to specific groups, making messages more relevant and boosting sales.

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %% [markdown]
# Q6. Generate synthetic data using make_blobs(n_samples=300, centers=4),
# apply KMeans clustering, and visualize the results with cluster centers.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X, _ = make_blobs(n_samples=300, centers=4, random_state=0)
kmeans = KMeans(n_clusters=4)
y_kmeans = kmeans.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='X')
plt.show()

# %% [markdown]
# Q7. Load the Wine dataset, apply StandardScaler , and then train a DBSCAN
# model. Print the number of clusters found (excluding noise).

# %%
# DBSCAN on Wine Dataset

from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import numpy as np

wine = load_wine()
X = StandardScaler().fit_transform(wine.data)
dbscan = DBSCAN(eps=1.5, min_samples=3)
labels = dbscan.fit_predict(X)
n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
print("Number of clusters:", n_clusters)
# Out:
# Number of clusters: 8

# %% [markdown]
# Q8. Generate moon-shaped synthetic data using
# make_moons(n_samples=200, noise=0.1), apply DBSCAN, and highlight the outliers in
# the plot.

# %%
# Moon Data with DBSCAN

from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

X, _ = make_moons(n_samples=200, noise=0.1)
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=labels)
outliers = X[labels == -1]
plt.scatter(outliers[:, 0], outliers[:, 1], c='red', marker='x')
plt.show()

# %% [markdown]
# Q9. Load the Wine dataset, reduce it to 2D using PCA, then apply
# Agglomerative Clustering and visualize the result in 2D with a scatter plot.

# %%
#Wine Data, PCA + Agglomerative Clustering

from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt

wine = load_wine()
X = StandardScaler().fit_transform(wine.data)
X_pca = PCA(n_components=2).fit_transform(X)
agglo = AgglomerativeClustering(n_clusters=3)
labels = agglo.fit_predict(X_pca)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels)
plt.show()

# %%
# Questions

'''
This is answers
'''
# Out:
# '\nThis is answers\n'
